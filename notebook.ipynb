# %%
from zipfile import ZipFile
import re
import pandas as pd
import datetime

booknames = pd.read_csv('books.csv').set_index('BookName')['BookID']

def get_output_zip():
    timestamp = datetime.datetime.isoformat(datetime.datetime.now()).replace('-', '').replace('T', '').replace(':','').split('.')[0]
    output_file_name = f'/Users/davidmorton/Downloads/output_{timestamp}.epub'
    return ZipFile(output_file_name, 'x')

def get_book_order(book:str):
    if book in booknames.keys():
        return booknames[book]
    return 0

def sanitize_book_name(book:str):
    otherbooks = {
        "Ps": "Psalms",
        "Psalm": "Psalms",
        "Isa": "Isaiah",
        'Eccl':'Ecclesiastes',
        'Dan':'Daniel',
        '1 Cor':'1 Corinthians',
        'Gen':'Genesis',
        'Rev':'Revelation',
        'Rom':'Romans',
        '1 Tim':'1 Timothy',
        'Matt':'Matthew',
        '1 Pet':'1 Peter',
        '2 Cor':'2 Corinthians',
        'Ge':'Genesis'
    }

    if book in otherbooks.keys():
        book = otherbooks[book]

    if book not in booknames.keys():
        print(f'Warning! {book} is not in booknames')
    return book

def divide_file(content:str):
    divisions = []

    start = 0
    regex = '((?:[123] )?[a-zA-Z]+) (\\d+)\\:(\\d+)(?:[-–](\\d+))?'
    matches = re.finditer(regex, content)

    for match in matches:
        groups = list(match.groups())
        book = sanitize_book_name(groups[0])
        book_order = get_book_order(book)
        chapter = int(groups[1])
        verse_start = int(groups[2])
        verse_end = verse_start if groups[3] is None else int(groups[3])

        reference = f"{book} {chapter}:{verse_start}{('' if verse_end == verse_start else (f'-{verse_end}'))}"

        ref_start = match.start()
        ref_end = match.end()
        divisions.append(content[start:ref_start])
        divisions.append((content[ref_start:ref_end], book_order, book, chapter, verse_start, verse_end, reference))
        start = ref_end

    divisions.append(content[start:])
        
    return divisions

def refigure_file(filename, divisions):
    output = ''
    references = []
    current_index = 1
    for x in divisions:
        if type(x) == str:
            output = output + x
        else:
            text, book_order, book, chapter, verse_start, verse_end, reference = x
            text = f"<a class='scripture-ref' id='ref{current_index}'/>{reference}"
            output += text
            references += [(f'{filename}#ref{current_index}', book_order, book, chapter, verse_start, verse_end, reference)]
            current_index = current_index + 1

    return output, references
        
def update_content_opf(content):
    content = (content
               .replace('</manifest>', '    <item href="sections/scripture_index.xhtml" id="scripture-index" media-type="application/xhtml+xml"/></manifest>')
               .replace('</spine>', '<itemref idref="scripture-index"/></spine>')
    )
    return content

def update_navmap(content):
    content = (content
               .replace('</navMap>', '<navPoint class="document" id="scripture-index" playOrder="17"><navLabel><text>Appendix E: Scripture Index</text></navLabel><content src="sections/scripture_index.xhtml"/></navPoint></navMap>')
               )
    return content     

def update_toc(content):
    content = (content
               .replace('</body>', '<p class="toc-para"><span class="toc-entry"><a href="scripture_index.xhtml">Appendix E: Scripture Index</a></span></p></body>')) 
    return content     

def update_styleshee(content):
    content = content + '''
.idx-book-p {
  background-color: transparent;
  line-height: 100%;
  margin: .05in 0 0.05in 0;
  text-align: justify;
}
.idx-book-span {
  font-family: "Open Sans", sans-serif;
  font-size: 12pt;
  font-weight: bold;
}
.idx-ref-p {
  background-color: transparent;
  margin: 0 0 0.0in .2in;
  text-align:justify;
}
.idx-ref-span {
  font-family: "Open Sans", sans-serif;
  font-size: 10pt;
  width: 25%;
  display:inline-block;
  text-align:top;
}
.idx-ref-scr-span {
  font-family: "Open Sans", sans-serif;
  font-size: 10pt;
  padding-right: 20px;
  display: inline-block;
  text-align:top;
}
.idx-ref-scr-div {
    display: inline;
}
.scripture-ref {
  color: inherit;
}'''
    return content

def add_index_page(output_zip, references):
    alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    refs = pd.DataFrame(references, columns=['file', 'order','book','chapter','start','end','reference'])
    print(refs.dtypes)
    refs = refs[refs['order'] != 0]
    refs = refs.sort_values(by=['order', 'chapter', 'start','end'])
    refs['file'] = refs['file'].str.replace('OEBPS/sections/', '')
    index_table = '<?xml version="1.0" encoding="UTF-8"?><html xmlns="http://www.w3.org/1999/xhtml"><head><link href="../styles/stylesheet.css" rel="stylesheet" type="text/css"/></head><body class="body0" xmlns:epub="http://www.idpf.org/2007/ops">'
    index_table += '<p class="para2"><span class="span4">Appendix E: Scripture Index</span></p>'
    for book_group in refs.groupby(by=['order','book']):
        bookname:str = book_group[0][1]
        index_table += f"<p class='idx-book-p'><span class='idx-book-span'>{book_group[0][1]}</span></p>"
        print(bookname.upper())
        for ref_group in book_group[1].groupby(by=['chapter','start','end','reference']):
            print(ref_group[0])
            ref_display_name = ref_group[0][3].replace(bookname, '').strip()
            index_table += f"<p class='idx-ref-p'><span class='idx-ref-span'>{ref_display_name}</span>"
            for i,row in enumerate(ref_group[1].itertuples()):
                index_table += f"<span class='idx-ref-scr-span'><a href='{row.file}'>{alphabet[i]}</a></span>"
            index_table += f"</p>\n"

    index_table += '</body></html>'

    output_zip.writestr('OEBPS/sections/scripture_index.xhtml', bytes(index_table, encoding='utf-8'))


def add_scripture_index_to_file(source):
    references = []

    z = ZipFile(source)
    output_zip = get_output_zip()

    for item in z.filelist:
        bcontent = z.read(item)
        if item.filename.endswith('.xhtml'):
            content = bcontent.decode('utf-8')
            divisions = divide_file(content)
            content, new_refs = refigure_file(item.filename, divisions)
            bcontent = bytes(content, 'utf-8')
            references += new_refs
        if 'content.opf' in item.filename:
            bcontent = bytes(update_content_opf(bcontent.decode('utf-8')), 'utf-8')
        if 'toc.ncx' in item.filename:
            bcontent = bytes(update_navmap(bcontent.decode('utf-8')), 'utf-8')
        if 'section0002.xhtml' in item.filename: # Table of contents
            bcontent = bytes(update_toc(bcontent.decode('utf-8')), 'utf-8')
        if 'stylesheet.css' in item.filename:
            bcontent = bytes(update_styleshee(bcontent.decode('utf-8')), 'utf-8')
            
        output_zip.writestr(item.filename, bcontent)

    add_index_page(output_zip, references)
    output_zip.close()
    return output_zip.filename

file_name = '/Users/davidmorton/Downloads/Awake, Oh Sleeper! - David Morton.epub'
print(add_scripture_index_to_file(file_name))
# Out:
# Warning! In is not in booknames
# Warning! in is not in booknames
# Warning! of is not in booknames
# Warning! at is not in booknames
# file         object
# order         int64
# book         object
# chapter       int64
# start         int64
# end           int64
# reference    object
# dtype: object
# GENESIS
# (1, 1, 1, 'Genesis 1:1')
# (1, 1, 2, 'Genesis 1:1-2')
# (1, 2, 2, 'Genesis 1:2')
# (1, 3, 3, 'Genesis 1:3')
# (1, 4, 4, 'Genesis 1:4')
# (1, 5, 5, 'Genesis 1:5')
# (1, 27, 27, 'Genesis 1:27')
# (2, 5, 7, 'Genesis 2:5-7')
# (2, 8, 9, 'Genesis 2:8-9')
# (2, 15, 3, 'Genesis 2:15-3')
# (2, 17, 17, 'Genesis 2:17')
# (3, 6, 7, 'Genesis 3:6-7')
# (3, 19, 19, 'Genesis 3:19')
# (3, 22, 22, 'Genesis 3:22')
# (3, 22, 24, 'Genesis 3:22-24')
# (4, 9, 9, 'Genesis 4:9')
# (6, 3, 3, 'Genesis 6:3')
# (7, 15, 15, 'Genesis 7:15')
# EXODUS
# (14, 19, 20, 'Exodus 14:19-20')
# (14, 21, 22, 'Exodus 14:21-22')
# (14, 28, 28, 'Exodus 14:28')
# LEVITICUS
# (16, 2, 2, 'Leviticus 16:2')
# (16, 17, 17, 'Leviticus 16:17')
# 1 SAMUEL
# (2, 6, 6, '1 Samuel 2:6')
# 1 KINGS
# (2, 42, 42, '1 Kings 2:42')
# JOB
# (7, 9, 10, 'Job 7:9-10')
# (14, 10, 15, 'Job 14:10-15')
# (33, 12, 12, 'Job 33:12')
# (34, 14, 15, 'Job 34:14-15')
# PSALMS
# (1, 6, 6, 'Psalms 1:6')
# (6, 5, 5, 'Psalms 6:5')
# (16, 10, 10, 'Psalms 16:10')
# (22, 24, 24, 'Psalms 22:24')
# (30, 3, 3, 'Psalms 30:3')
# (30, 5, 5, 'Psalms 30:5')
# (37, 2, 2, 'Psalms 37:2')
# (37, 9, 10, 'Psalms 37:9-10')
# (37, 12, 12, 'Psalms 37:12')
# (37, 20, 20, 'Psalms 37:20')
# (37, 38, 38, 'Psalms 37:38')
# (49, 14, 15, 'Psalms 49:14-15')
# (50, 3, 3, 'Psalms 50:3')
# (89, 48, 48, 'Psalms 89:48')
# (97, 3, 3, 'Psalms 97:3')
# (103, 9, 9, 'Psalms 103:9')
# (104, 29, 30, 'Psalms 104:29-30')
# (112, 10, 10, 'Psalms 112:10')
# (115, 17, 17, 'Psalms 115:17')
# PROVERBS
# (12, 7, 7, 'Proverbs 12:7')
# (14, 12, 12, 'Proverbs 14:12')
# (24, 20, 20, 'Proverbs 24:20')
# ECCLESIASTES
# (3, 18, 21, 'Ecclesiastes 3:18-21')
# (9, 10, 10, 'Ecclesiastes 9:10')
# (12, 7, 7, 'Ecclesiastes 12:7')
# ISAIAH
# (1, 28, 28, 'Isaiah 1:28')
# (1, 31, 31, 'Isaiah 1:31')
# (29, 5, 6, 'Isaiah 29:5-6')
# (34, 9, 10, 'Isaiah 34:9-10')
# (38, 18, 18, 'Isaiah 38:18')
# (53, 7, 11, 'Isaiah 53:7-11')
# (66, 13, 13, 'Isaiah 66:13')
# (66, 16, 16, 'Isaiah 66:16')
# (66, 24, 24, 'Isaiah 66:24')
# JEREMIAH
# (17, 9, 9, 'Jeremiah 17:9')
# (17, 27, 27, 'Jeremiah 17:27')
# LAMENTATIONS
# (2, 16, 16, 'Lamentations 2:16')
# EZEKIEL
# (20, 47, 47, 'Ezekiel 20:47')
# (28, 9, 9, 'Ezekiel 28:9')
# (37, 3, 5, 'Ezekiel 37:3-5')
# DANIEL
# (12, 2, 2, 'Daniel 12:2')
# HOSEA
# (13, 14, 14, 'Hosea 13:14')
# MICAH
# (7, 18, 18, 'Micah 7:18')
# NAHUM
# (1, 10, 10, 'Nahum 1:10')
# MALACHI
# (4, 1, 1, 'Malachi 4:1')
# MATTHEW
# (3, 12, 12, 'Matthew 3:12')
# (5, 11, 12, 'Matthew 5:11-12')
# (5, 25, 26, 'Matthew 5:25-26')
# (5, 26, 26, 'Matthew 5:26')
# (7, 13, 13, 'Matthew 7:13')
# (9, 23, 26, 'Matthew 9:23-26')
# (10, 28, 28, 'Matthew 10:28')
# (10, 39, 39, 'Matthew 10:39')
# (11, 28, 28, 'Matthew 11:28')
# (12, 40, 40, 'Matthew 12:40')
# (16, 20, 20, 'Matthew 16:20')
# (16, 27, 27, 'Matthew 16:27')
# (19, 29, 29, 'Matthew 19:29')
# (24, 27, 27, 'Matthew 24:27')
# (25, 1, 6, 'Matthew 25:1-6')
# (25, 14, 30, 'Matthew 25:14-30')
# (25, 24, 24, 'Matthew 25:24')
# (25, 31, 31, 'Matthew 25:31')
# (25, 46, 46, 'Matthew 25:46')
# (27, 46, 46, 'Matthew 27:46')
# MARK
# (6, 32, 34, 'Mark 6:32-34')
# (9, 47, 48, 'Mark 9:47-48')
# (10, 29, 31, 'Mark 10:29-31')
# LUKE
# (16, 22, 24, 'Luke 16:22-24')
# (17, 26, 27, 'Luke 17:26-27')
# (17, 29, 29, 'Luke 17:29')
# (17, 30, 30, 'Luke 17:30')
# (22, 46, 46, 'Luke 22:46')
# (23, 42, 43, 'Luke 23:42-43')
# (24, 22, 24, 'Luke 24:22-24')
# (24, 31, 31, 'Luke 24:31')
# (24, 39, 39, 'Luke 24:39')
# JOHN
# (2, 2, 2, 'John 2:2')
# (3, 16, 16, 'John 3:16')
# (5, 24, 24, 'John 5:24')
# (5, 28, 29, 'John 5:28-29')
# (6, 53, 59, 'John 6:53-59')
# (6, 56, 58, 'John 6:56-58')
# (8, 51, 51, 'John 8:51')
# (10, 18, 18, 'John 10:18')
# (11, 11, 11, 'John 11:11')
# (11, 17, 26, 'John 11:17-26')
# (11, 25, 25, 'John 11:25')
# (14, 1, 1, 'John 14:1')
# (14, 1, 4, 'John 14:1-4')
# (14, 3, 3, 'John 14:3')
# (14, 14, 14, 'John 14:14')
# (14, 18, 18, 'John 14:18')
# (15, 6, 6, 'John 15:6')
# (15, 13, 13, 'John 15:13')
# (17, 12, 12, 'John 17:12')
# (20, 17, 17, 'John 20:17')
# (21, 18, 18, 'John 21:18')
# ACTS
# (1, 11, 11, 'Acts 1:11')
# (17, 32, 32, 'Acts 17:32')
# (23, 6, 8, 'Acts 23:6-8')
# (24, 10, 21, 'Acts 24:10-21')
# (24, 14, 15, 'Acts 24:14-15')
# (24, 15, 15, 'Acts 24:15')
# ROMANS
# (1, 32, 32, 'Romans 1:32')
# (2, 7, 7, 'Romans 2:7')
# (2, 16, 16, 'Romans 2:16')
# (4, 25, 25, 'Romans 4:25')
# (5, 8, 8, 'Romans 5:8')
# (6, 21, 21, 'Romans 6:21')
# (6, 22, 22, 'Romans 6:22')
# (6, 23, 23, 'Romans 6:23')
# (7, 5, 5, 'Romans 7:5')
# (8, 11, 11, 'Romans 8:11')
# (8, 23, 23, 'Romans 8:23')
# (9, 22, 22, 'Romans 9:22')
# (14, 8, 9, 'Romans 14:8-9')
# 1 CORINTHIANS
# (1, 7, 7, '1 Corinthians 1:7')
# (3, 17, 17, '1 Corinthians 3:17')
# (4, 16, 17, '1 Corinthians 4:16-17')
# (5, 1, 10, '1 Corinthians 5:1-10')
# (6, 2, 2, '1 Corinthians 6:2')
# (11, 30, 30, '1 Corinthians 11:30')
# (12, 3, 4, '1 Corinthians 12:3-4')
# (15, 6, 6, '1 Corinthians 15:6')
# (15, 14, 14, '1 Corinthians 15:14')
# (15, 18, 20, '1 Corinthians 15:18-20')
# (15, 21, 22, '1 Corinthians 15:21-22')
# (15, 26, 26, '1 Corinthians 15:26')
# (15, 30, 30, '1 Corinthians 15:30')
# (15, 42, 44, '1 Corinthians 15:42-44')
# (15, 51, 51, '1 Corinthians 15:51')
# (15, 51, 52, '1 Corinthians 15:51-52')
# (15, 53, 53, '1 Corinthians 15:53')
# (15, 53, 54, '1 Corinthians 15:53-54')
# 2 CORINTHIANS
# (2, 16, 16, '2 Corinthians 2:16')
# (4, 17, 17, '2 Corinthians 4:17')
# (5, 1, 10, '2 Corinthians 5:1-10')
# (5, 2, 4, '2 Corinthians 5:2-4')
# (7, 10, 10, '2 Corinthians 7:10')
# GALATIANS
# (6, 8, 8, 'Galatians 6:8')
# EPHESIANS
# (4, 7, 10, 'Ephesians 4:7-10')
# (5, 14, 14, 'Ephesians 5:14')
# PHILIPPIANS
# (1, 28, 28, 'Philippians 1:28')
# (3, 10, 10, 'Philippians 3:10')
# (3, 19, 19, 'Philippians 3:19')
# COLOSSIANS
# (1, 17, 17, 'Colossians 1:17')
# 1 THESSALONIANS
# (2, 3, 3, '1 Thessalonians 2:3')
# (2, 19, 19, '1 Thessalonians 2:19')
# (4, 13, 18, '1 Thessalonians 4:13-18')
# (4, 14, 14, '1 Thessalonians 4:14')
# (4, 14, 15, '1 Thessalonians 4:14-15')
# (4, 16, 16, '1 Thessalonians 4:16')
# (5, 3, 3, '1 Thessalonians 5:3')
# (5, 10, 10, '1 Thessalonians 5:10')
# 2 THESSALONIANS
# (1, 7, 7, '2 Thessalonians 1:7')
# (1, 9, 9, '2 Thessalonians 1:9')
# 1 TIMOTHY
# (3, 16, 16, '1 Timothy 3:16')
# (6, 9, 9, '1 Timothy 6:9')
# (6, 15, 16, '1 Timothy 6:15-16')
# HEBREWS
# (1, 3, 3, 'Hebrews 1:3')
# (2, 17, 17, 'Hebrews 2:17')
# (4, 15, 15, 'Hebrews 4:15')
# (5, 12, 12, 'Hebrews 5:12')
# (6, 1, 1, 'Hebrews 6:1')
# (6, 8, 8, 'Hebrews 6:8')
# (9, 7, 7, 'Hebrews 9:7')
# (9, 27, 27, 'Hebrews 9:27')
# (9, 27, 28, 'Hebrews 9:27-28')
# (10, 11, 11, 'Hebrews 10:11')
# (10, 39, 39, 'Hebrews 10:39')
# (11, 35, 35, 'Hebrews 11:35')
# (11, 35, 40, 'Hebrews 11:35-40')
# (11, 39, 40, 'Hebrews 11:39-40')
# (12, 2, 2, 'Hebrews 12:2')
# (12, 2, 3, 'Hebrews 12:2-3')
# JAMES
# (1, 15, 15, 'James 1:15')
# (2, 26, 26, 'James 2:26')
# (4, 12, 12, 'James 4:12')
# (5, 20, 20, 'James 5:20')
# 1 PETER
# (1, 3, 9, '1 Peter 1:3-9')
# (2, 18, 21, '1 Peter 2:18-21')
# (2, 22, 22, '1 Peter 2:22')
# (3, 18, 18, '1 Peter 3:18')
# (4, 13, 13, '1 Peter 4:13')
# 2 PETER
# (2, 1, 1, '2 Peter 2:1')
# (2, 3, 3, '2 Peter 2:3')
# (2, 12, 12, '2 Peter 2:12')
# (3, 4, 4, '2 Peter 3:4')
# (3, 7, 7, '2 Peter 3:7')
# 1 JOHN
# (1, 2, 2, '1 John 1:2')
# (3, 16, 16, '1 John 3:16')
# (4, 10, 10, '1 John 4:10')
# (4, 10, 11, '1 John 4:10-11')
# (4, 18, 18, '1 John 4:18')
# (5, 16, 17, '1 John 5:16-17')
# REVELATION
# (1, 7, 7, 'Revelation 1:7')
# (1, 18, 18, 'Revelation 1:18')
# (2, 7, 7, 'Revelation 2:7')
# (2, 8, 8, 'Revelation 2:8')
# (3, 3, 3, 'Revelation 3:3')
# (6, 9, 11, 'Revelation 6:9-11')
# (11, 18, 18, 'Revelation 11:18')
# (14, 9, 13, 'Revelation 14:9-13')
# (20, 10, 15, 'Revelation 20:10-15')
# (20, 11, 11, 'Revelation 20:11')
# (20, 14, 15, 'Revelation 20:14-15')
# (21, 1, 2, 'Revelation 21:1-2')
# (21, 1, 4, 'Revelation 21:1-4')
# (21, 4, 4, 'Revelation 21:4')
# (22, 1, 2, 'Revelation 22:1-2')
# (22, 1, 5, 'Revelation 22:1-5')
# (22, 7, 7, 'Revelation 22:7')
# /Users/davidmorton/Downloads/output_20230506065257.epub

# %%
output_zip.filename
# Out:
# '/Users/davidmorton/Downloads/output_20230505170001.epub'

# %%
for info in z.filelist:
    if info.filename == 'mimetype':
        print(z.read(info))
    print(info)
# Out:
# b'application/epub+zip'
# <ZipInfo filename='mimetype' filemode='-rw-r--r--' file_size=20>
# <ZipInfo filename='inside-title.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=488 compress_size=293>
# <ZipInfo filename='META-INF/container.xml' compress_type=deflate filemode='-rw-r--r--' file_size=239 compress_size=168>
# <ZipInfo filename='META-INF/calibre_bookmarks.txt' compress_type=deflate filemode='-rw-r--r--' file_size=200 compress_size=169>
# <ZipInfo filename='OEBPS/CrimsonText-Bold.otf' compress_type=deflate filemode='-rw-r--r--' file_size=201204 compress_size=78315>
# <ZipInfo filename='OEBPS/toc.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=1340 compress_size=434>
# <ZipInfo filename='OEBPS/content.opf' compress_type=deflate filemode='-rw-r--r--' file_size=4748 compress_size=1054>
# <ZipInfo filename='OEBPS/CrimsonText-BoldItalic.otf' compress_type=deflate filemode='-rw-r--r--' file_size=208596 compress_size=83448>
# <ZipInfo filename='OEBPS/CrimsonText-Italic.otf' compress_type=deflate filemode='-rw-r--r--' file_size=201220 compress_size=81907>
# <ZipInfo filename='OEBPS/OpenSans-VariableFont_wdth,wght.otf' compress_type=deflate filemode='-rw-r--r--' file_size=241148 compress_size=116721>
# <ZipInfo filename='OEBPS/toc.ncx' compress_type=deflate filemode='-rw-r--r--' file_size=2862 compress_size=579>
# <ZipInfo filename='OEBPS/CrimsonText-Regular.otf' compress_type=deflate filemode='-rw-r--r--' file_size=201264 compress_size=80110>
# <ZipInfo filename='OEBPS/sections/section0001.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=1562 compress_size=724>
# <ZipInfo filename='OEBPS/sections/section0003.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=6761 compress_size=2465>
# <ZipInfo filename='OEBPS/sections/section0007.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=68999 compress_size=19706>
# <ZipInfo filename='OEBPS/sections/section0005.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=58961 compress_size=16977>
# <ZipInfo filename='OEBPS/sections/section0002.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=1924 compress_size=500>
# <ZipInfo filename='OEBPS/sections/section0004.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=10047 compress_size=3787>
# <ZipInfo filename='OEBPS/sections/section0006.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=62495 compress_size=17221>
# <ZipInfo filename='OEBPS/sections/section0013.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=2573 compress_size=1172>
# <ZipInfo filename='OEBPS/sections/section0008.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=40433 compress_size=12072>
# <ZipInfo filename='OEBPS/sections/section0011.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=27618 compress_size=8219>
# <ZipInfo filename='OEBPS/sections/section0015.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=12285 compress_size=3878>
# <ZipInfo filename='OEBPS/sections/section0017.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=2309 compress_size=1023>
# <ZipInfo filename='OEBPS/sections/section0009.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=38541 compress_size=11996>
# <ZipInfo filename='OEBPS/sections/section0010.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=57396 compress_size=16498>
# <ZipInfo filename='OEBPS/sections/section0012.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=29340 compress_size=9516>
# <ZipInfo filename='OEBPS/sections/section0016.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=11269 compress_size=3840>
# <ZipInfo filename='OEBPS/sections/section0014.xhtml' compress_type=deflate filemode='-rw-r--r--' file_size=47905 compress_size=15030>
# <ZipInfo filename='OEBPS/images/image0004.jpg' compress_type=deflate filemode='-rw-r--r--' file_size=82826 compress_size=59631>
# <ZipInfo filename='OEBPS/images/image0005.jpg' compress_type=deflate filemode='-rw-r--r--' file_size=49505 compress_size=33461>
# <ZipInfo filename='OEBPS/images/image0001.png' compress_type=deflate filemode='-rw-r--r--' file_size=858020 compress_size=858250>
# <ZipInfo filename='OEBPS/images/image0002.png' compress_type=deflate filemode='-rw-r--r--' file_size=70652 compress_size=62580>
# <ZipInfo filename='OEBPS/images/image0003.jpg' compress_type=deflate filemode='-rw-r--r--' file_size=145451 compress_size=113934>
# <ZipInfo filename='OEBPS/images/dropped_image.png' compress_type=deflate filemode='-rw-r--r--' file_size=96120 compress_size=83137>
# <ZipInfo filename='OEBPS/styles/stylesheet.css' compress_type=deflate filemode='-rw-r--r--' file_size=6431 compress_size=1275>

# %%
z = ZipFile(file_name)
output_zip = get_output_zip()

for f in z.filelist:
    output_zip.writestr(f.filename, z.read(f))
output_zip.close()
